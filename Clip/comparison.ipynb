# %%
vlm_file  = "40_results_vlm.jsonl"
clip_file = "zeroshot_40sample_results.jsonl"

# %%
import pandas as pd, json, os

# %%
df_clip = pd.read_json(clip_file, lines=True)
df_clip = df_clip.rename(columns={
    "path": "image",
    "label": "clip_label",
    "confidence": "clip_conf"
})

# %%
df_vlm = pd.read_json(vlm_file, lines=True)
df_vlm = pd.concat([df_vlm.drop(["result"], axis=1), df_vlm["result"].apply(pd.Series)], axis=1)
df_vlm = df_vlm.rename(columns={
    "scene_type": "vlm_label",
    "confidence_0_1": "vlm_conf"
})

# %%
# --- Extract filename keys (ignore path + extension) ---
df_clip["image_key"] = df_clip["image"].apply(lambda x: os.path.splitext(os.path.basename(str(x)))[0])
df_vlm["image_key"]  = df_vlm["image"].apply(lambda x: os.path.splitext(os.path.basename(str(x)))[0])

# Quick label counts before merge
print("CLIP label distribution:\n", df_clip["clip_label"].value_counts(), "\n")
print("VLM label distribution:\n", df_vlm["vlm_label"].value_counts(), "\n")
# Out:
# CLIP label distribution:
#  clip_label
# unknown             17
# MEDIA_PROPAGANDA    12
# PROTEST_STREET      11
# Name: count, dtype: int64
#
# VLM label distribution:
#  vlm_label
# unknown                11
# PROTEST_STREET         11
# MEDIA_PROPAGANDA       10
# CAMPUS_EVENT            5
# INSTITUTIONAL_STAGE     3
# Name: count, dtype: int64

# %%
merged = pd.merge(df_clip, df_vlm, on="image_key", how="inner")
print(f"✅ Merged {len(merged)} images successfully")

merged[["image_key", "clip_label", "vlm_label", "clip_conf", "vlm_conf", "caption_20w"]]
# Out:
# ✅ Merged 40 images successfully
#                                                                 image_key  \
# 0    2848410766023731083__284529430_340934021319534_2343800145217192904_n
# 1    2848410766023731083__284645805_787670909264484_7131751097966912843_n
# 2    2849126906832291056__284356575_713238196573997_2663972127010493414_n
# 3    2849656145477240143__284645804_755471129155733_5979343260691737113_n
# 4   2983720566764124471__501685915_1256993622499792_3932324816662002823_n
# 5                         451343914_496616053018135_2586767934785121431_n
# 6                        452842052_1017585399767829_1218373299653330229_n
# 7                         452856948_815909363643449_8261195655921378787_n
# 8                          452857080_7906272059485882_13013324345258530_n
# 9                          452859706_502781995554325_267712069011515191_n
# 10                        453563777_974250051117426_1767248277498375702_n
# 11                        453572434_506140301894449_6106889659304587118_n
# 12                        453572435_7995532140534527_544302348809111960_n
# 13                       453575633_1183387739531482_2309473526383923461_n
# 14                       453583954_1550032105600963_4043760404323128717_n
# 15                      453594531_18299024983167367_4882855109073420694_n
# 16                       453649574_1672755530191245_5293498686781486983_n
# 17                       453649749_1172530290722911_2780898197846000733_n
# 18                       453655750_1170378434079398_5628869442975325461_n
# 19                        453711093_507842881766735_2546005444853884001_n
# 20                        453711520_952804193286259_7974871928834171757_n
# 21                       453714419_1711852752917390_4947390332304106168_n
# 22                        453724925_954110906485063_5654869655745022697_n
# 23                       453730578_1464628234258248_8867724087952116423_n
# 24                        453749328_871347104857259_8595131216029232409_n
# 25                      453777040_17955548645802471_6326517283566018121_n
# 26                      453779234_17955548663802471_4332469261439864094_n
# 27                       453781696_1028980711944801_1502017658109313874_n
# 28                        453813678_404742955425744_3330767030418778740_n
# 29                        453835422_921009019788849_7481756272065361455_n
# 30                        453870647_813719407193174_7319414399549221100_n
# 31                        453888340_1583134279277204_878036164309545409_n
# 32                          453902886_507492171959190_66452212404026010_n
# 33                        453928993_511348844671773_4398976818895296807_n
# 34                        453945675_467951279379434_5553962586864959758_n
# 35                       453957126_2113273439073620_4665835693356773396_n
# 36                       453963858_1380113316725389_3849273822277756344_n
# 37                       453964735_1276307649998595_1627353059633745706_n
# 38                       453965466_1155938239026443_4872174925114905562_n
# 39                        453981706_508209624909817_1625174020715573180_n
#
#           clip_label            vlm_label  clip_conf  vlm_conf  \
# 0            unknown         CAMPUS_EVENT      0.743       0.0
# 1     PROTEST_STREET       PROTEST_STREET      0.952       0.9
# 2            unknown         CAMPUS_EVENT      0.509       0.0
# 3            unknown     MEDIA_PROPAGANDA      0.268       0.9
# 4     PROTEST_STREET       PROTEST_STREET      0.946       0.9
# 5   MEDIA_PROPAGANDA              unknown      0.948       0.0
# 6            unknown     MEDIA_PROPAGANDA      0.659       0.8
# 7   MEDIA_PROPAGANDA         CAMPUS_EVENT      0.803       0.0
# 8            unknown         CAMPUS_EVENT      0.664       0.0
# 9     PROTEST_STREET       PROTEST_STREET      0.912       0.9
# 10           unknown  INSTITUTIONAL_STAGE      0.652       0.9
# 11    PROTEST_STREET       PROTEST_STREET      0.871       0.9
# 12           unknown              unknown      0.697       0.0
# 13  MEDIA_PROPAGANDA              unknown      0.803       0.0
# 14  MEDIA_PROPAGANDA              unknown      0.783       0.0
# 15           unknown         CAMPUS_EVENT      0.640       0.0
# 16  MEDIA_PROPAGANDA              unknown      0.888       0.0
# 17  MEDIA_PROPAGANDA     MEDIA_PROPAGANDA      0.873       0.9
# 18    PROTEST_STREET       PROTEST_STREET      0.886       0.9
# 19    PROTEST_STREET       PROTEST_STREET      0.962       0.9
# 20           unknown              unknown      0.650       0.0
# 21           unknown              unknown      0.557       0.0
# 22  MEDIA_PROPAGANDA     MEDIA_PROPAGANDA      0.804       0.9
# 23           unknown  INSTITUTIONAL_STAGE      0.622       0.9
# 24  MEDIA_PROPAGANDA     MEDIA_PROPAGANDA      0.963       0.9
# 25    PROTEST_STREET       PROTEST_STREET      0.983       0.9
# 26    PROTEST_STREET       PROTEST_STREET      0.983       0.9
# 27    PROTEST_STREET       PROTEST_STREET      0.932       0.9
# 28           unknown              unknown      0.662       0.0
# 29  MEDIA_PROPAGANDA     MEDIA_PROPAGANDA      0.965       0.0
# 30    PROTEST_STREET       PROTEST_STREET      0.987       0.9
# 31  MEDIA_PROPAGANDA              unknown      0.885       0.0
# 32    PROTEST_STREET       PROTEST_STREET      0.923       0.9
# 33  MEDIA_PROPAGANDA     MEDIA_PROPAGANDA      0.872       0.9
# 34           unknown     MEDIA_PROPAGANDA      0.599       0.9
# 35           unknown  INSTITUTIONAL_STAGE      0.712       0.9
# 36  MEDIA_PROPAGANDA              unknown      0.903       0.0
# 37           unknown              unknown      0.662       0.0
# 38           unknown     MEDIA_PROPAGANDA      0.488       0.9
# 39           unknown     MEDIA_PROPAGANDA      0.550       0.9
#
#                                                      caption_20w
# 0                  a group of people sitting in chairs in a room
# 1      Group of people protesting for better UCLA transit system
# 2                                  MTSAC MSA 2ND GENERAL MEETING
# 3                              Statement of Opposition to SB1412
# 4                     People protesting in the street with signs
# 5                                   woman wearing hijab speaking
# 6                                   Woman speaking at CPOC event
# 7                       diver on platform at Paris 2024 Olympics
# 8                                         music class in session
# 9   Two women protest on a bridge with a sign criticizing Israel
# 10                       Group of people posing with CAIR banner
# 11                        People protesting with flags and signs
# 12
# 13                                         newborn baby sleeping
# 14
# 15                       group of people sitting on a stone wall
# 16
# 17                                    Turkey restricts Instagram
# 18                                      Men and boy waving flags
# 19                           People protest with signs and flags
# 20                     a pile of trash and garbage on the ground
# 21
# 22            Child sits amidst rubble with 'STOP GENOCIDE' text
# 23                               Oxnard High School Hall of Fame
# 24         Injured children in hospital with urgent text overlay
# 25                   Protesters hold Palestinian flags and signs
# 26                        people protesting with signs and flags
# 27                      Man holding Palestinian flags in a crowd
# 28
# 29                                 screenshot of a GoFundMe page
# 30                        A crowd marches with Palestinian flags
# 31                   Boy standing against wall with text overlay
# 32          Person holding Palestinian flags on highway overpass
# 33          Child with skin condition and political text overlay
# 34                        Woman with text overlay and party logo
# 35                    CAIR California ribbon cutting celebration
# 36                                   young boy with text overlay
# 37                                   a child in a destroyed city
# 38                               The People's Mural event poster
# 39                   Black August 365 Commemorating Black August

# %%
# How many images both models labeled as "unknown"
both_unknown = merged[
    (merged["clip_label"].str.lower() == "unknown") &
    (merged["vlm_label"].str.lower() == "unknown")
]

print(f"🟡 Both CLIP and VLM labeled 'unknown': {len(both_unknown)} images")
# Out:
# 🟡 Both CLIP and VLM labeled 'unknown': 5 images

# %%
# Count how many images share the same label in both models
overlap_counts = merged[merged["clip_label"] == merged["vlm_label"]]["clip_label"].value_counts()

print(" Overlapping label counts (same label in both models):")
print(overlap_counts)
# Out:
#  Overlapping label counts (same label in both models):
# clip_label
# PROTEST_STREET      11
# unknown              5
# MEDIA_PROPAGANDA     5
# Name: count, dtype: int64

# %%
unknown_captions = merged[merged["vlm_label"] == "unknown"][["image_key", "vlm_label", "vlm_conf", "caption_20w"]]
print(f"🟡 {len(unknown_captions)} images labeled 'unknown' by VLM\n")
pd.set_option('max_colwidth', None)
display(unknown_captions)
# Out:
# 🟡 11 images labeled 'unknown' by VLM
#                                            image_key vlm_label  vlm_conf  \
# 5    451343914_496616053018135_2586767934785121431_n   unknown       0.0
# 12   453572435_7995532140534527_544302348809111960_n   unknown       0.0
# 13  453575633_1183387739531482_2309473526383923461_n   unknown       0.0
# 14  453583954_1550032105600963_4043760404323128717_n   unknown       0.0
# 16  453649574_1672755530191245_5293498686781486983_n   unknown       0.0
# 20   453711520_952804193286259_7974871928834171757_n   unknown       0.0
# 21  453714419_1711852752917390_4947390332304106168_n   unknown       0.0
# 28   453813678_404742955425744_3330767030418778740_n   unknown       0.0
# 31   453888340_1583134279277204_878036164309545409_n   unknown       0.0
# 36  453963858_1380113316725389_3849273822277756344_n   unknown       0.0
# 37  453964735_1276307649998595_1627353059633745706_n   unknown       0.0
#
#                                     caption_20w
# 5                  woman wearing hijab speaking
# 12
# 13                        newborn baby sleeping
# 14
# 16
# 20    a pile of trash and garbage on the ground
# 21
# 28
# 31  Boy standing against wall with text overlay
# 36                  young boy with text overlay
# 37                  a child in a destroyed city
